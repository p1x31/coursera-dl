# %%
import numpy as np
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.11.0

# %%
tf.compat.v1.disable_v2_behavior()
#init w = 0
w = tf.Variable(0, dtype=tf.float32)
#define cost function
cost = tf.add(tf.add(w**2, tf.multiply(-10.,2)),25)
#learning algo
train = tf.compat.v1.train.GradientDescentOptimizer(0.01). minimize(cost)

init = tf.compat.v1.global_variables_initializer()
session = tf.compat.v1.Session()
#initialize global variables

session.run(init)
print(session.run(w))
# Out:
# WARNING:tensorflow:From /home/vadim/anaconda3/envs/latest_tf/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 0.0
# 2023-01-24 19:40:15.661278: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 19:40:15.661921: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 19:40:15.662230: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 19:40:15.662579: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 19:40:15.662837: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 19:40:15.663042: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 937 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-01-24 19:40:15.663804: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:357] MLIR V1 optimization pass is not enabled

# %%
#run one step of gradient descent
session.run(train)
#evaluate w after one step of gradient descent
print(session.run(w))
# Out:
# 0.0

# %%
for i in range(1000):
    session.run(train)
print(session.run(w))
# Out:
# 0.0

# %%
# Out:
# /bin/bash: tf_upgrade_v2.py: command not found
